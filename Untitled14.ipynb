# %% [markdown]
# <a href="https://colab.research.google.com/github/thegurdian/ML/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

x = np.array([4, 2])
w = np.array([0.5, 0.3])
b = 1

z = np.dot(x, w) + b

# ReLU activation
output = max(0, z)

print(output)
# Out:
# 3.6

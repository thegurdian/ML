# %% [markdown]
# <a href="https://colab.research.google.com/github/thegurdian/ML/blob/main/One_Hot_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder


# Data
df = pd.DataFrame({
    'city': ['Dhaka', 'Chittagong', 'Khulna', 'Dhaka'],
    'age': [20, 25, 30, 22],
    'buy': [1, 0, 1, 1]
})

# Encode
encoder = OneHotEncoder(sparse_output=False)
city_encoded = encoder.fit_transform(df[['city']])

# Convert to DataFrame
city_df = pd.DataFrame(city_encoded, columns=encoder.get_feature_names_out())

# Merge
df = pd.concat([df.drop('city', axis=1), city_df], axis=1)

print(df)
# Out:
#    age  buy  city_Chittagong  city_Dhaka  city_Khulna
# 0   20    1              0.0         1.0          0.0
# 1   25    0              1.0         0.0          0.0
# 2   30    1              0.0         0.0          1.0
# 3   22    1              0.0         1.0          0.0

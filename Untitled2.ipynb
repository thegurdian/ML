# %% [markdown]
# <a href="https://colab.research.google.com/github/thegurdian/ML/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "study_hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "sleep_hours": [4, 5, 6, 5, 7, 6, 8, 7],
    "pass":        [0, 0, 0, 0, 1, 1, 1, 1]
}

df = pd.DataFrame(data)
print(df)
X = df[["study_hours", "sleep_hours"]]
y = df["pass"]
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X, y)
print(model.predict([[3, 5]]))  # Expected: 0 (Fail)
print(model.predict([[7, 7]]))  # Expected: 1 (Pass)
# Out:
#    study_hours  sleep_hours  pass
# 0            1            4     0
# 1            2            5     0
# 2            3            6     0
# 3            4            5     0
# 4            5            7     1
# 5            6            6     1
# 6            7            8     1
# 7            8            7     1
# [0]
# [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
